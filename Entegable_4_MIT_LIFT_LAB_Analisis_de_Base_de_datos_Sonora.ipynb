# %% [markdown]
# <a href="https://colab.research.google.com/github/anaiainza-ux/Analisis-Nanotiendas-MIT/blob/main/Entegable_4_MIT_LIFT_LAB_Analisis_de_Base_de_datos_Sonora.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MIT LIFT LAB Analisis de Base de datos Sonora
#
# Ana Isabel Ainza Acosta
# Paola
# Nico

# %%
import pandas as pd
import numpy as np

# %%
ds = pd.read_excel('Datos_Primarios.xlsx',sheet_name='Tec_Norte')

# %% [markdown]
# # Limpiando la Base

# %%
ds.head()
# Out:
#      Fecha registrada  Latitud Aproximada  Longitud Aproximada  \
# 0                 NaT                 NaN                  NaN
# 1 2024-09-30 19:45:57             25.7442            -100.3103
# 2 2024-09-30 19:45:57             25.7442            -100.3103
# 3 2024-09-30 19:48:19             28.8500            -106.2773
# 4 2024-09-30 20:03:23             25.7442            -100.3103
#
#                Nombre del Encuestador o Encuestadora  \
# 0                                                NaN
# 1  Raul Gerardo Villarreal García _ Tecnológico d...
# 2                                          Sebastian
# 3                       Mariana Georgina Loya Pérez
# 4                  Yashir Elías Fernández Chavarría
#
#                     Tipo de negocio  \
# 0                               NaN
# 1  Miscelanea o Tienda de Abarrotes
# 2  Miscelanea o Tienda de Abarrotes
# 3  Miscelanea o Tienda de Abarrotes
# 4  Miscelanea o Tienda de Abarrotes
#
# ...

# %%
Son= ds[ds.Campus=="Sonora Norte"].copy() #Solo datos Sonora Norte

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Son.head()
# Out:
#        Fecha registrada  Latitud Aproximada  Longitud Aproximada  \
# 82  2024-10-24 18:09:23             29.0248            -111.4740
# 83  2024-10-24 18:12:15             29.0248            -111.4740
# 554 2024-11-11 09:25:10             29.1826            -111.3631
# 555 2024-11-11 09:26:04             29.1826            -111.3631
# 558 2024-11-11 12:58:02             47.6034            -122.3414
#
#     Nombre del Encuestador o Encuestadora         Tipo de negocio  \
# 82                                      .                Pollería
# 83                                    CFR                Pollería
# 554                                    na  Cervecería o licorería
# 555                                  Juan                Pollería
# 558            SALON303EQUIPO1SONORANORTE             Tortillería
#
#     ¿El negocio tiene reja para entrar? (¿los consumidores pueden entrar a la tienda para escoger y comprar los productos?)  \
# ...

# %% [markdown]
# # Explorando la base de datos
#
# tenemos un total de 102 entradas para sonora

# %%
# Revisando que tipo de variables tiene la base
#La Base de datos ya separada a solo datos Sonora Norte
Son.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 102 entries, 82 to 693
# Data columns (total 43 columns):
#  #   Column                                                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                                                              --------------  -----
#  0   Fecha registrada                                                                                                                                                    102 non-null    datetime64[ns]
#  1   Latitud Aproximada                                                                                                                                                  101 non-null    float64
# ...

# %% [markdown]
# Con la funcion .info ya logramos apreciar cuantas respuestas tenemos en cada columna y que tipo de variables son entonces coemnzamos a revisar cada columna.

# %% [markdown]
# # Revisión y limpieza de datos

# %%
#Columna uno
Son['Fecha registrada'].unique()
# Si tenmos 102 datos de hora
# Out:
# <DatetimeArray>
# ['2024-10-24 18:09:23', '2024-10-24 18:12:15', '2024-11-11 09:25:10',
#  '2024-11-11 09:26:04', '2024-11-11 12:58:02', '2024-11-12 15:03:30',
#  '2024-11-12 15:16:25', '2024-11-12 15:29:12', '2024-11-12 15:41:54',
#  '2024-11-12 15:43:16',
#  ...
#  '2024-11-18 23:26:28', '2024-11-19 00:38:22', '2024-11-19 00:41:13',
#  '2024-11-19 00:44:20', '2024-11-19 00:44:33', '2024-11-19 00:47:46',
#  '2024-11-19 00:47:58', '2024-11-19 09:42:56', '2024-11-19 09:54:47',
#  '2024-11-19 10:57:39']
# Length: 102, dtype: datetime64[ns]

# %%
# Columna 2
Son['Latitud Aproximada'].unique()

#Encontrmos un resitro nulo
#Ahora eliminamos esa fila ya que nos dimos cuenta que toda es nula

toDrop= Son[Son['Latitud Aproximada'].isna()].index #Guardamos en varible to drop para eliminar fila
Son.drop(toDrop,inplace=True)

# %%
Son.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 101 entries, 82 to 692
# Data columns (total 43 columns):
#  #   Column                                                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                                                              --------------  -----
#  0   Fecha registrada                                                                                                                                                    101 non-null    datetime64[ns]
#  1   Latitud Aproximada                                                                                                                                                  101 non-null    float64
# ...

# %% [markdown]
# Ahora tenemo 101 datos utiles

# %%
#Confirmamos que se elimino
#Columna 2:
Son['Latitud Aproximada'].unique()
# Out:
# array([29.0248, 29.1826, 47.6034, 32.4041, 24.567 , 25.6759, 19.4342,
#        19.4504, 28.6009, 24.8013, 24.6738, 24.8665, 33.508 , 31.7365,
#        33.5892, 29.0593, 28.9275, 24.6753, 29.0982, 28.9739, 24.6823,
#        29.1475, 28.8411, 24.574 , 28.878 ])

# %%
# Columna 3:
Son['Longitud Aproximada'].unique()
# Out:
# array([-111.474 , -111.3631, -122.3414, -116.8198, -107.385 , -100.3208,
#         -99.0559,  -99.1934, -111.3874, -107.3866, -107.4577, -107.4773,
#        -112.0995, -106.4592, -111.8379, -110.8172, -106.4313, -107.4417,
#        -110.9749, -111.1577, -107.2749, -110.8931, -111.0403, -107.4289,
#        -111.2518])

# %%
# Columna 4:
Son['Tipo de negocio'].unique()
# Out:
# array(['Pollería', 'Cervecería o licorería', 'Tortillería',
#        'Miscelanea o Tienda de Abarrotes', 'Dulcería',
#        'Verdulería o Frutería', 'Cafetería', 'Carnicería',
#        'Fondita/Mini Resutaurante', 'Panadería'], dtype=object)

# %%
# Columna 5:
Son['Horario de apertura'].unique()
# Out:
# array([datetime.time(10, 30), datetime.time(7, 0), datetime.time(6, 30),
#        datetime.time(9, 0), datetime.time(8, 0), datetime.time(10, 0),
#        datetime.time(9, 30), datetime.time(8, 30), datetime.time(6, 0),
#        datetime.time(12, 0), datetime.time(7, 30), datetime.time(11, 0),
#        datetime.time(13, 0)], dtype=object)

# %%
Son['¿El negocio tiene reja para entrar? (¿los consumidores pueden entrar a la tienda para escoger y comprar los productos?)'].unique()
# Confrimamos
# Out:
# array(['Sí', 'No'], dtype=object)

# %%
# Columna 6
Son['Nombre del negocio'].unique()
# Out:
# array(['.', 'La Polleria de Toño', 'na', 'Santa laguna',
#        'Issa Productos Regionales', 'Fomi creaciones', 'vanikas\xa0',
#        'La parda del sabor', 'La tiendita de 10$',
#        'ABARROTES "SAN FRANCISCO"', 'La pasadita',
#        'Tortillas De Harina De La Abuela', 'Mobella',
#        'Carolina Cosmeticos', 'El Zaino', 'Kailani', 'Abarrotes Gilda',
#        'Abarrotes El Ozi', 'Tortillería Lola\xa0', 'abarrotes don caro',
#        'Rr', 'Puesto ambulante Uriel\xa0', 'Abarrotes el tata',
#        'Espitia moda y accesorios y frutería\xa0', 'Dulcería Moderna\xa0',
#        'El chapucero café\xa0', 'a', 'Expendio', 'Taqueria Huez',
#        'Torilleria el Centro', 'Café Cele', 'Country Taco', 'China Leo',
#        1, 'Abarrotes Modelo', 'Refresqueria tatay', 'La pazadita', 'Huez',
#        'Spitia verduleria', 'Club fiesta', 'Candiani',
#        'Todo precio mayoreo', 'Hui Wei', 'Tienda de diez del Centro',
#        'Tortillas de harina 5 estrellas', 'Global Marquet\xa0',
# ...

# %%
#Columna 7
# Confrimando que tenmos datos solo de Sonora Norte
Son['Campus'].unique()
# Out:
# array(['Sonora Norte'], dtype=object)

# %%
# Columna 8
Son['Año de apertura del negocio'].unique()
# Out:
# array([1987., 1980., 1995., 2020., 2014., 2022., 2021., 2023., 2010.,
#        1999., 2018., 1997., 2008., 2015., 2024., 2012., 2001., 2003.,
#        1985., 1984., 2004., 1991., 1990., 2019., 2013., 1989., 2009.,
#        2000., 1983., 2016., 2006., 2005., 2002., 1986., 1994., 2007.,
#        1996.])

# %%
# Columna 9
Son['¿Cuántas personas trabajaron para este negocio (con o sin paga) durante el mes anterior?'].unique()
# Que no son el dueño
# Out:
# array([2, 5, '0 - Sólo trabaja el dueño o dueña', 3, 6, 7, 9, 4, 10, 1, 8],
#       dtype=object)

# %%
# convertimos las repuestas de: 0 - Sólo trabaja el dueño o dueña a solo 0
Son['¿Cuántas personas trabajaron para este negocio (con o sin paga) durante el mes anterior?'] =Son['¿Cuántas personas trabajaron para este negocio (con o sin paga) durante el mes anterior?'].replace({'0 - Sólo trabaja el dueño o dueña' : 0})
# Out:
# <ipython-input-31-a00df20804e4>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Son['¿Cuántas personas trabajaron para este negocio (con o sin paga) durante el mes anterior?'] =Son['¿Cuántas personas trabajaron para este negocio (con o sin paga) durante el mes anterior?'].replace({'0 - Sólo trabaja el dueño o dueña' : 0})

# %%
#Confriamos que columna 9 ahora es solo numerica:
Son['¿Cuántas personas trabajaron para este negocio (con o sin paga) durante el mes anterior?'].unique()
# Out:
# array([ 2,  5,  0,  3,  6,  7,  9,  4, 10,  1,  8])

# %%
#Columna 10
Son['¿Cuántas personas trabajaron con un salario fijo durante el último mes?'].unique()
# Out:
# array([ 1.,  2., 10.,  0.,  4.,  3.,  6.,  7.,  5.,  8.,  9.])

# %%
# Columna 11
Son['En tres meses, ¿esperas que el número total de trabajadores del negocio aumente, disminuya o permanezca igual?'].unique()
# Out:
# array(['Disminuya', 'Permanezca igual', 'Aumente'], dtype=object)

# %%
# Convirtiendo a numerica : 'En tres meses, ¿esperas que el número total de trabajadores del negocio aumente, disminuya o permanezca igual?'
Son['En tres meses, ¿esperas que el número total de trabajadores del negocio aumente, disminuya o permanezca igual?'] = Son['En tres meses, ¿esperas que el número total de trabajadores del negocio aumente, disminuya o permanezca igual?'].replace({'Permanezca igual': 2 , 'Disminuya': 1 , "Aumente":3})
Son['En tres meses, ¿esperas que el número total de trabajadores del negocio aumente, disminuya o permanezca igual?'].unique()
# Out:
# <ipython-input-35-21e53dd96ad5>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Son['En tres meses, ¿esperas que el número total de trabajadores del negocio aumente, disminuya o permanezca igual?'] = Son['En tres meses, ¿esperas que el número total de trabajadores del negocio aumente, disminuya o permanezca igual?'].replace({'Permanezca igual': 2 , 'Disminuya': 1 , "Aumente":3})
# array([1, 2, 3])

# %%
# Columna 12
# Tenmos 99 respuestas revisaremos cuales faltan
Son['Durante el último mes, ¿tuviste más, menos, o el mismo número de clientes en tu negocio?'].fillna('Igual',inplace=True)
# Ya que los resultados esperados son mas menos o igual, asumiremos que los nulos son   que las ventas permanecieron iguales
# Out:
# <ipython-input-36-aa22b710d3fe>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Son['Durante el último mes, ¿tuviste más, menos, o el mismo número de clientes en tu negocio?'].fillna('Igual',inplace=True)

# %%
# Columna 12 lista:
Son['Durante el último mes, ¿tuviste más, menos, o el mismo número de clientes en tu negocio?'].unique()
# Out:
# array(['Igual', 'Más', 'Menos'], dtype=object)

# %%
# Convirtiendo variable: 'Durante el último mes, ¿tuviste más, menos, o el mismo número de clientes en tu negocio?'
# Cambiando la columna tipo de numeros a palabras

Son["Durante el último mes, ¿tuviste más, menos, o el mismo número de clientes en tu negocio?"] = Son["Durante el último mes, ¿tuviste más, menos, o el mismo número de clientes en tu negocio?"].replace({"Igual": 2 , "Menos": 1 , "Más":3})
Son['Durante el último mes, ¿tuviste más, menos, o el mismo número de clientes en tu negocio?'].unique()
# Out:
# <ipython-input-38-33edb28e8e6a>:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Son["Durante el último mes, ¿tuviste más, menos, o el mismo número de clientes en tu negocio?"] = Son["Durante el último mes, ¿tuviste más, menos, o el mismo número de clientes en tu negocio?"].replace({"Igual": 2 , "Menos": 1 , "Más":3})
# array([2, 3, 1])

# %%
# Columna 13 :
Son['¿Esperas que en tres meses tengas más, menos o el mismo número de clientes en tu negocio?'].fillna('El mismo número de clientes',inplace=True)
# Se hara el mismo tratemiento que en la columna pasada
# Out:
# <ipython-input-39-b66916480173>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Son['¿Esperas que en tres meses tengas más, menos o el mismo número de clientes en tu negocio?'].fillna('El mismo número de clientes',inplace=True)

# %%
# Columna 13 corregida:
Son['¿Esperas que en tres meses tengas más, menos o el mismo número de clientes en tu negocio?'].unique()
# Out:
# array(['El mismo número de clientes', 'Más', 'Menos'], dtype=object)

# %%
# Convertir a numericas: '¿Esperas que en tres meses tengas más, menos o el mismo número de clientes en tu negocio?'
Son['¿Esperas que en tres meses tengas más, menos o el mismo número de clientes en tu negocio?'] = Son['¿Esperas que en tres meses tengas más, menos o el mismo número de clientes en tu negocio?'].replace({'El mismo número de clientes': 2 , 'Menos': 1 , 'Más':3})
Son['¿Esperas que en tres meses tengas más, menos o el mismo número de clientes en tu negocio?'].unique()
# Out:
# <ipython-input-41-38ea08c184f4>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Son['¿Esperas que en tres meses tengas más, menos o el mismo número de clientes en tu negocio?'] = Son['¿Esperas que en tres meses tengas más, menos o el mismo número de clientes en tu negocio?'].replace({'El mismo número de clientes': 2 , 'Menos': 1 , 'Más':3})
# array([2, 3, 1])

# %%
# Columna 14
Son['¿Tus ventas actuales están mejor, peor o igual en comparación con hace un mes?']
# Out:
# 82     Mejor
# 83      Peor
# 554     Peor
# 555    Mejor
# 558    Mejor
#        ...
# 688    Igual
# 689    Igual
# 690    Igual
# 691     Peor
# 692    Igual
# Name: ¿Tus ventas actuales están mejor, peor o igual en comparación con hace un mes?, Length: 101, dtype: object

# %%
# Columna 15
Son['¿Por qué piensas que las ventas incrementaron/disminuyeron/permanecieron igual? (opcional)'].unique()

# Ya que es pregunta cualitativa y opcional no importa la cantidad de respuestas
# Tenmos solo 52 entradas
# Vamos a miliar para elimina \xa0 de las respuestas
# Out:
# array(['calor', 'por la carestia', nan, '.',
#        'Incrementan o disminuyen por las temporadas. Por ejemplo: el regreso a clases, visperas decembrinas, expo y semana santa.p',
#        'por temporada', 'Por fecha festiva (diciembre)', 'Temporada',
#        'mas gente', 'Mas mercancia mas accesible', 'temporada\xa0',
#        'las calles en remodelacion tiendas chinas',
#        'Porque agregaron más productos\xa0',
#        'Ya muchos conocen la tortilleria', '65t',
#        'Por fechas de sembrina\xa0', 'Fechas de sembrina\xa0',
#        'Gobierno, delincuencia, estado de la economía\xa0',
#        'Aumento de salario mínimo, sube prófugo por esto',
#        'Temporada de cafés\xa0', 'no se',
#        'por las fechas, ya qué hay más dinero',
#        'Porque ya estan pagando el aguinaldo',
#        'Porque están subiendo mucho las cosas, como harina manteca, productos',
#        'El calor los afectó mucho\xa0',
#        'Ya que están empezando las vacaciones y aguinaldos',
# ...

# %%
# Columna 16
Son['¿Esperas que las ventas de tu negocio en tres meses sean mayores, menores o iguales?'].unique()
# Out:
# array(['Mayores', 'Menores', 'Iguales'], dtype=object)

# %%
# Convertir a numerica: '¿Esperas que las ventas de tu negocio en tres meses sean mayores, menores o iguales?'
Son['¿Esperas que las ventas de tu negocio en tres meses sean mayores, menores o iguales?'] = Son['¿Esperas que las ventas de tu negocio en tres meses sean mayores, menores o iguales?'].replace({'Iguales': 2 , 'Menores': 1 , 'Mayores':3})
Son['¿Esperas que las ventas de tu negocio en tres meses sean mayores, menores o iguales?'].unique()
# Out:
# <ipython-input-45-658c0270b8a5>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Son['¿Esperas que las ventas de tu negocio en tres meses sean mayores, menores o iguales?'] = Son['¿Esperas que las ventas de tu negocio en tres meses sean mayores, menores o iguales?'].replace({'Iguales': 2 , 'Menores': 1 , 'Mayores':3})
# array([3, 1, 2])

# %%
# Columna 17
Son['¿Durante el último mes tu nivel de inventario aumentó, disminuyó o permaneció igual?']
# Out:
# 82     Permaneció igual
# 83            Disminuyó
# 554             Aumentó
# 555             Aumentó
# 558             Aumentó
#              ...
# 688    Permaneció igual
# 689             Aumentó
# 690    Permaneció igual
# 691           Disminuyó
# 692             Aumentó
# Name: ¿Durante el último mes tu nivel de inventario aumentó, disminuyó o permaneció igual?, Length: 101, dtype: object

# %%
# Columna 18
Son['¿Esperas que dentro de tres meses el nivel de inventario incremente, disminuya o permanezca igual?'].unique()
# Out:
# array(['Disminuya', 'Incremente', 'Permanezca igual'], dtype=object)

# %%
# Convertir a numerica: '¿Esperas que dentro de tres meses el nivel de inventario incremente, disminuya o permanezca igual?'
Son['¿Esperas que dentro de tres meses el nivel de inventario incremente, disminuya o permanezca igual?'] = Son['¿Esperas que dentro de tres meses el nivel de inventario incremente, disminuya o permanezca igual?'].replace({'Permanezca igual':2 , 'Disminuya':1 , 'Incremente':3})
Son['¿Esperas que dentro de tres meses el nivel de inventario incremente, disminuya o permanezca igual?'].unique()
# Out:
# <ipython-input-48-e08d54ddddbf>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Son['¿Esperas que dentro de tres meses el nivel de inventario incremente, disminuya o permanezca igual?'] = Son['¿Esperas que dentro de tres meses el nivel de inventario incremente, disminuya o permanezca igual?'].replace({'Permanezca igual':2 , 'Disminuya':1 , 'Incremente':3})
# array([1, 3, 2])

# %%
# Columna 19
Son['Actualmente, ¿sientes que tu nivel de inventario es demasiado grande, muy poco o está en su nivel correcto?'].unique()
# Out:
# array(['En su nivel correcto', 'Muy poco', 'Demsiado grande'],
#       dtype=object)

# %%
# convertir a numerica: 'Actualmente, ¿sientes que tu nivel de inventario es demasiado grande, muy poco o está en su nivel correcto?'
Son['Actualmente, ¿sientes que tu nivel de inventario es demasiado grande, muy poco o está en su nivel correcto?'] = Son['Actualmente, ¿sientes que tu nivel de inventario es demasiado grande, muy poco o está en su nivel correcto?'].replace({'En su nivel correcto': 2 , 'Muy poco': 1 , 'Demsiado grande':3})
Son['Actualmente, ¿sientes que tu nivel de inventario es demasiado grande, muy poco o está en su nivel correcto?'].unique()
# Out:
# <ipython-input-50-b154688793cc>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Son['Actualmente, ¿sientes que tu nivel de inventario es demasiado grande, muy poco o está en su nivel correcto?'] = Son['Actualmente, ¿sientes que tu nivel de inventario es demasiado grande, muy poco o está en su nivel correcto?'].replace({'En su nivel correcto': 2 , 'Muy poco': 1 , 'Demsiado grande':3})
# array([2, 1, 3])

# %%
# Columna 20
Son['En promedio, ¿el precio de venta de los productos que vende este establecimiento aumentó, bajó o permaneció igual a hace un mes?'].unique()
# Out:
# array(['Aumentó', 'Permaneció igual', 'Bajó'], dtype=object)

# %%
# numerica; 'En promedio, ¿el precio de venta de los productos que vende este establecimiento aumentó, bajó o permaneció igual a hace un mes?'
Son['En promedio, ¿el precio de venta de los productos que vende este establecimiento aumentó, bajó o permaneció igual a hace un mes?'] = Son['En promedio, ¿el precio de venta de los productos que vende este establecimiento aumentó, bajó o permaneció igual a hace un mes?'].replace({'Permaneció igual': 2 , 'Bajó': 1 , 'Aumentó':3})
Son['En promedio, ¿el precio de venta de los productos que vende este establecimiento aumentó, bajó o permaneció igual a hace un mes?'].unique()
# Out:
# <ipython-input-52-5fe94cfb0f7c>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Son['En promedio, ¿el precio de venta de los productos que vende este establecimiento aumentó, bajó o permaneció igual a hace un mes?'] = Son['En promedio, ¿el precio de venta de los productos que vende este establecimiento aumentó, bajó o permaneció igual a hace un mes?'].replace({'Permaneció igual': 2 , 'Bajó': 1 , 'Aumentó':3})
# array([3, 2, 1])

# %%
# Columna 21
Son['¿Dentro de tres meses, esperas que los precios de los productos que vendes aumenten, disminuyan o permanezcan igual?'].unique()
# Out:
# array(['Disminuyan', 'Aumenten', 'Permanezcan igual'], dtype=object)

# %%
# Columna 22
Son['Qué tanto impacta a tu negocio: - El crimen'].unique()
# Out:
# array(['Mucho', 'Moderado', 'Algo', 'Nada', 'Poco'], dtype=object)

# %%
# Columna 23
Son['Qué tanto impacta a tu negocio: - La falta de crédito'].unique()
# Out:
# array(['Mucho', 'Moderado', 'Algo', 'Poco', 'Nada'], dtype=object)

# %%
# Columna 24
Son['Qué tanto impacta a tu negocio: - El incremento en el precio de los bienes'].unique()
# Out:
# array(['Algo', 'Moderado', 'Mucho', 'Poco', 'Nada'], dtype=object)

# %%
# Columna 25
Son['Qué tanto impacta a tu negocio: - La competencia'].unique()
# Out:
# array(['Algo', 'Moderado', 'Poco', 'Mucho', 'Nada'], dtype=object)

# %%
#  convietiendo las 3 'Qué tanto impacta a tu negocio
columnsToDummie=['Qué tanto impacta a tu negocio: - El crimen','Qué tanto impacta a tu negocio: - El incremento en el precio de los bienes','Qué tanto impacta a tu negocio: - La competencia' ]
D = pd.get_dummies(Son[columnsToDummie])
df_head = D.head()
df_head
#variables categoricas a binarias (dummies)
# Out:
#      Qué tanto impacta a tu negocio: - El crimen_Algo  \
# 82                                              False
# 83                                              False
# 554                                              True
# 555                                             False
# 558                                             False
#
#      Qué tanto impacta a tu negocio: - El crimen_Moderado  \
# 82                                               False
# 83                                                True
# 554                                              False
# 555                                              False
# 558                                              False
#
#      Qué tanto impacta a tu negocio: - El crimen_Mucho  \
# 82                                                True
# 83                                               False
# 554                                              False
# 555                                              False
# ...

# %%
# Columna 26
Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Bancos'].unique()
#Y que esta es una pregunta de si o no de varias opciones de donde recibiste creditos asi que toamremos los datos nulos como no creditos de este tipo.
# Out:
# array([nan, 'Sí', 'No'], dtype=object)

# %%
# Correciones columnas 26
# Vamos a checar las variables nulas
Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Bancos'].fillna('No',inplace=True)
# Out:
# <ipython-input-60-3c96c4dd6fb0>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Bancos'].fillna('No',inplace=True)

# %%
# Revisando columna 26
Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Bancos'].unique()
# Out:
# array(['No', 'Sí'], dtype=object)

# %%
# Convertir a numerica: '¿Esperas que las ventas de tu negocio en tres meses sean mayores, menores o iguales?'
Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Bancos'] = Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Bancos'].replace({'No': 0 , 'Sí': 1 })
Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Bancos'].unique()
# Out:
# <ipython-input-62-5765f21eaabf>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Bancos'] = Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Bancos'].replace({'No': 0 , 'Sí': 1 })
# array([0, 1])

# %%
# Columna 27
Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Proveedores'].unique()
# Out:
# array([nan, 'Sí', 'No'], dtype=object)

# %%
# Remplzar nulos de columna 27
Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Proveedores'].fillna('No',inplace=True)
# Revisando 27
Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Proveedores'].unique()
# Out:
# <ipython-input-64-c58a30efe13d>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Proveedores'].fillna('No',inplace=True)
# array(['No', 'Sí'], dtype=object)

# %%
# Convertir a numerica: '¿Esperas que las ventas de tu negocio en tres meses sean mayores, menores o iguales?'
Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Proveedores'] = Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Proveedores'].replace({'No': 0 , 'Sí': 1 })
Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Proveedores'].unique()
# Out:
# <ipython-input-65-d0f48e4c5e12>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Proveedores'] = Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Proveedores'].replace({'No': 0 , 'Sí': 1 })
# array([0, 1])

# %%
# Columna 28
Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Familia'].unique()
# Out:
# array(['Sí', 'No', nan], dtype=object)

# %%
# Remplzar nulos de columna 28
Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Familia'].fillna('No',inplace=True)
# Revisando 28
Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Familia'].unique()
# Out:
# <ipython-input-67-e318c2ccabdf>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Familia'].fillna('No',inplace=True)
# array(['Sí', 'No'], dtype=object)

# %%
# Convertir a numerica: '¿Esperas que las ventas de tu negocio en tres meses sean mayores, menores o iguales?'
Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Familia'] = Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Familia'].replace({'No': 0 , 'Sí': 1 })
Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Familia'].unique()
# Out:
# <ipython-input-68-aefe2b8fba1b>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Familia'] = Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Familia'].replace({'No': 0 , 'Sí': 1 })
# array([1, 0])

# %%
# Columna 29
Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Gobierno'].unique()
# Out:
# array(['No', 'Sí', nan], dtype=object)

# %%
# Remplzar nulos de columna 29
Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Gobierno'].fillna('No',inplace=True)
# Revisando 28
Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Gobierno'].unique()
# Out:
# <ipython-input-70-3fb8eeda8cf9>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Gobierno'].fillna('No',inplace=True)
# array(['No', 'Sí'], dtype=object)

# %%
# Columna 30
Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Ahorros populares (tandas)'].unique()
# Out:
# array(['Sí', 'No', nan], dtype=object)

# %%
# Remplzar nulos de columna 30
Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Ahorros populares (tandas)'].fillna('No',inplace=True)
# Revisando 30
Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Ahorros populares (tandas)'].unique()
# Out:
# <ipython-input-72-5cf4e7b02ed2>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Ahorros populares (tandas)'].fillna('No',inplace=True)
# array(['Sí', 'No'], dtype=object)

# %%
# Convertir a numerica
Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Ahorros populares (tandas)'] = Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Ahorros populares (tandas)'].replace({'No': 0 , 'Sí': 1 })
Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Ahorros populares (tandas)'].unique()
# Out:
# <ipython-input-73-f8eb47057b14>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Ahorros populares (tandas)'] = Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Ahorros populares (tandas)'].replace({'No': 0 , 'Sí': 1 })
# array([1, 0])

# %%
# Columna 31
Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Crédito privado'].unique()
# Out:
# array([nan, 'Sí', 'No'], dtype=object)

# %%
# Remplzar nulos de columna 31
Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Crédito privado'].fillna('No',inplace=True)
# Revisando 30
Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Crédito privado'].unique()
# Out:
# <ipython-input-75-88e4b60683fe>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Crédito privado'].fillna('No',inplace=True)
# array(['No', 'Sí'], dtype=object)

# %%
# Columna 32
Son['¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? Otro (OPCIONAL)'].unique()
# Out:
# array([nan, 'Xrf4 r', 'BBVA', 'Familia', 'Familia y Credito privado',
#        'Proveedores y familia', 'Proveedor crédito de 15 dias'],
#       dtype=object)

# %%
# Columna 33
Son['¿Cuál es la razón principal por la que tu negocio no tiene un crédito bancario?'].unique()
# Out:
# array(['No creo que me lo aprobarían', nan,
#        'Los requerimientos de garantía son muy altos',
#        'Los procedimientos para aplicar son complicados',
#        'No necesito un crédito', 'Las tasas de interés son muy altas',
#        'No me queda cerca algún banco'], dtype=object)

# %%
# Columna 34
Son['Asume que tienes los medios para hacer crecer tu negocio, ¿quisieras que tu negocio creciera? (por ejemplo, con más empleados, más productos, un local más grande)'].unique()
# Out:
# array(['Sí', 'No'], dtype=object)

# %%
Son["Asume que tienes los medios para hacer crecer tu negocio, ¿quisieras que tu negocio creciera? (por ejemplo, con más empleados, más productos, un local más grande)"] = Son["Asume que tienes los medios para hacer crecer tu negocio, ¿quisieras que tu negocio creciera? (por ejemplo, con más empleados, más productos, un local más grande)"].replace({"Sí":1 , "No":0})
Son['Asume que tienes los medios para hacer crecer tu negocio, ¿quisieras que tu negocio creciera? (por ejemplo, con más empleados, más productos, un local más grande)'].unique()
# Out:
# <ipython-input-79-b1b144319fdc>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Son["Asume que tienes los medios para hacer crecer tu negocio, ¿quisieras que tu negocio creciera? (por ejemplo, con más empleados, más productos, un local más grande)"] = Son["Asume que tienes los medios para hacer crecer tu negocio, ¿quisieras que tu negocio creciera? (por ejemplo, con más empleados, más productos, un local más grande)"].replace({"Sí":1 , "No":0})
# array([1, 0])

# %%
# Columna 35
Son['¿Cuál es la razón principal por la que no quieres que tu negocio crezca?'].unique()
# Variable cualitativa no entra a analisis.
# Viasulizar si son categorias con digrama de barras
# Out:
# array([nan, 'Porque tendría que hacer trámites muy costosos',
#        'Porque teme a la inseguridad',
#        'Porque sería muy complicado administrarlo',
#        'Porque está satisfecho con su negocio'], dtype=object)

# %%
# Columna 36
Son['¿Cuál sería el salario mensual más bajo que estaría dispuesto a aceptar para cerrar el negocio y'].unique()
# Out:
# array([10000, 23000, 'na', '.', 12000, 6000, 30000, 5000, 50000, 25000,
#        40000, 1500, 13000, 15000, nan, 65366, '$', 100000, 21100,
#        'salario mínimo\xa0', 18000, 9000, 211111, 20000, 35000, 45000,
#        'Cero', 200000, 'Nada', 4000, 'No lo tomaría\xa0', 60000,
#        'No lo tomaría', 'T', '22 mensuales', '0 pesos', 'F', 'D', 3000,
#        8000, 'No estaría dispuesta\xa0', 'Ninguno', '22 mil', 70000],
#       dtype=object)

# %%
# cambiando todas las variables de palabras por 0
cambio = ['na', '.', np.nan, '$','Cero','Nada', 'No lo tomaría\xa0',
       'No lo tomaría', 'T', '0 pesos', 'F', 'D', 'No estaría dispuesta\xa0', 'Ninguno']
indsToCh = Son[Son['¿Cuál sería el salario mensual más bajo que estaría dispuesto a aceptar para cerrar el negocio y'].isin(cambio)].index
Son.loc[indsToCh,'¿Cuál sería el salario mensual más bajo que estaría dispuesto a aceptar para cerrar el negocio y'] = 0
Son['¿Cuál sería el salario mensual más bajo que estaría dispuesto a aceptar para cerrar el negocio y'].unique()
# Out:
# array([10000, 23000, 0, 12000, 6000, 30000, 5000, 50000, 25000, 40000,
#        1500, 13000, 15000, 65366, 100000, 21100, 'salario mínimo\xa0',
#        18000, 9000, 211111, 20000, 35000, 45000, 200000, 4000, 60000,
#        '22 mensuales', 3000, 8000, '22 mil', 70000], dtype=object)

# %%
# Limpiando columna 36
# convertimos las repuestas de: 0 - Sólo trabaja el dueño o dueña a solo 0
#Todavia no ready
Son['¿Cuál sería el salario mensual más bajo que estaría dispuesto a aceptar para cerrar el negocio y'] =Son['¿Cuál sería el salario mensual más bajo que estaría dispuesto a aceptar para cerrar el negocio y'].replace({'22 mensuales' : 22000})
Son['¿Cuál sería el salario mensual más bajo que estaría dispuesto a aceptar para cerrar el negocio y'] =Son['¿Cuál sería el salario mensual más bajo que estaría dispuesto a aceptar para cerrar el negocio y'].replace({'22 mil' : 22000})
Son['¿Cuál sería el salario mensual más bajo que estaría dispuesto a aceptar para cerrar el negocio y'] =Son['¿Cuál sería el salario mensual más bajo que estaría dispuesto a aceptar para cerrar el negocio y'].replace({'salario mínimo\xa0' : 7468})
Son['¿Cuál sería el salario mensual más bajo que estaría dispuesto a aceptar para cerrar el negocio y'].fillna('0',inplace=True)
Son['¿Cuál sería el salario mensual más bajo que estaría dispuesto a aceptar para cerrar el negocio y'].unique()
Son['¿Cuál sería el salario mensual más bajo que estaría dispuesto a aceptar para cerrar el negocio y'].describe()
# Out:
# <ipython-input-83-3f7e0400f3e9>:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Son['¿Cuál sería el salario mensual más bajo que estaría dispuesto a aceptar para cerrar el negocio y'] =Son['¿Cuál sería el salario mensual más bajo que estaría dispuesto a aceptar para cerrar el negocio y'].replace({'salario mínimo\xa0' : 7468})
# <ipython-input-83-3f7e0400f3e9>:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
# Columna 37
Son['Horario de apertura'].unique()
# Out:
# array([datetime.time(10, 30), datetime.time(7, 0), datetime.time(6, 30),
#        datetime.time(9, 0), datetime.time(8, 0), datetime.time(10, 0),
#        datetime.time(9, 30), datetime.time(8, 30), datetime.time(6, 0),
#        datetime.time(12, 0), datetime.time(7, 30), datetime.time(11, 0),
#        datetime.time(13, 0)], dtype=object)

# %%
# Columna 38
Son['Horario de cierre'].unique()
# Out:
# array([datetime.time(13, 0), datetime.time(23, 0), datetime.time(16, 0),
#        datetime.time(18, 0), datetime.time(16, 30), datetime.time(19, 0),
#        datetime.time(21, 0), datetime.time(17, 30), datetime.time(18, 30),
#        datetime.time(17, 0), datetime.time(15, 0), datetime.time(14, 0),
#        datetime.time(20, 0), datetime.time(13, 30), datetime.time(20, 30),
#        datetime.time(14, 30), datetime.time(21, 30), datetime.time(22, 0),
#        datetime.time(19, 30)], dtype=object)

# %%
# Columna 38
Son['Sexo del dueño o dueña'].unique()
# Out:
# array(['Preferencia de no especificar', 'Mujer', 'Hombre'], dtype=object)

# %%
Son["Sexo del dueño o dueña"] = Son["Sexo del dueño o dueña"].replace({"Preferencia de no especificar":0 , "Mujer":1 , "Hombre":2})
Son['Sexo del dueño o dueña'].unique()
# Out:
# <ipython-input-87-1bb6d742d320>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Son["Sexo del dueño o dueña"] = Son["Sexo del dueño o dueña"].replace({"Preferencia de no especificar":0 , "Mujer":1 , "Hombre":2})
# array([0, 1, 2])

# %%
# Columna 39
Son['¿El local de su negocio es rentado o propio?'].unique()
# Out:
# array(['Rentado', 'Propio'], dtype=object)

# %%
Son["¿El local de su negocio es rentado o propio?"] = Son["¿El local de su negocio es rentado o propio?"].replace({"Rentado":0 , "Propio":1})
Son['Educación del dueño'].unique()
# Out:
# <ipython-input-89-480fdd131e76>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Son["¿El local de su negocio es rentado o propio?"] = Son["¿El local de su negocio es rentado o propio?"].replace({"Rentado":0 , "Propio":1})
# array(['Sin estudios', 'Preparatoria', 'Primaria', 'Universidad y más',
#        'Secundaria', nan], dtype=object)

# %%
# Columna 40
Son['Educación del dueño'].unique()
# Out:
# array(['Sin estudios', 'Preparatoria', 'Primaria', 'Universidad y más',
#        'Secundaria', nan], dtype=object)

# %%
# Columna 41
Son['Educación del dueño'].unique()
# Out:
# array(['Sin estudios', 'Preparatoria', 'Primaria', 'Universidad y más',
#        'Secundaria', nan], dtype=object)

# %%
Son["Educación del dueño"] = Son["Educación del dueño"].replace({"Sin estudios":0 , "Preparatoria":1 , "Primaria":2, "Secundaria":3, "Universidad y más": 4})
Son['Educación del dueño'].unique()
# Out:
# <ipython-input-92-3fea864bad91>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Son["Educación del dueño"] = Son["Educación del dueño"].replace({"Sin estudios":0 , "Preparatoria":1 , "Primaria":2, "Secundaria":3, "Universidad y más": 4})
# array([ 0.,  1.,  2.,  4.,  3., nan])

# %%
# Columna 42
Son['Edad del dueño o dueña'].unique()
# Out:
# array(['Más de 60', 'De 31 a 40', 'De 41 a 50', 'Menos de 20',
#        'De 21 a 30', 'De 51 a 60'], dtype=object)

# %%
Son["Edad del dueño o dueña"] = Son["Edad del dueño o dueña"].replace({"Menos de 20": 1 , "De 21 a 30": 2 , "De 31 a 40":3 , "De 41 a 50":4 , "De 51 a 60":5 , "Más de 60":6})
Son['Edad del dueño o dueña'].unique()
# Out:
# <ipython-input-94-d5ff7fa595dd>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Son["Edad del dueño o dueña"] = Son["Edad del dueño o dueña"].replace({"Menos de 20": 1 , "De 21 a 30": 2 , "De 31 a 40":3 , "De 41 a 50":4 , "De 51 a 60":5 , "Más de 60":6})
# array([6, 3, 4, 1, 2, 5])

# %% [markdown]
# # Convietiendo datos a numericos

# %% [markdown]
# # Generación de los modelos de análisis de datos

# %% [markdown]
# Identificar las variables relevantes de la BD para la solución del reto.
#
# Identificar el modelo de regresión a utilizar.
#
# Generar el modelo inicial utilizando el software de python (Colab).
#
# Interpretar los resultados obtenidos incluyendo los niveles de significancia y poder de la prueba.
#
# Mejorar el modelo mediante el uso y posible modificación de las variables.
#
# Generar escenarios de tomas de decisiones para las MYPES.

# %%
# convietiendo la variable de antiguedad de negocio a años
Son['Año de apertura del negocio'] = 2024 - Son['Año de apertura del negocio']
Son['Año de apertura del negocio'].unique()
# Out:
# array([37., 44., 29.,  4., 10.,  2.,  3.,  1., 14., 25.,  6., 27., 16.,
#         9.,  0., 12., 23., 21., 39., 40., 20., 33., 34.,  5., 11., 35.,
#        15., 24., 41.,  8., 18., 19., 22., 38., 30., 17., 28.])

# %% [markdown]
# NOtas jimmy Variable (x) =
# numero de personas y financaimento
# - mejorar meporar el negioco depnde de
# -crimer deteiente crecimeinto?

# %% [markdown]
# # Identificar las variables relevantes de la BD para la solución del reto.
#
# Variable dependiente (Y) =
# - 'Año de Apertura'
# - '¿Cuál sería el salario mensual más bajo que estaría dispuesto a aceptar para cerrar el negocio y'
#
#
#
# Variable (x):
# '¿Cuántas personas trabajaron para este negocio (con o sin paga) durante el mes anterior?',
# '¿Cuántas personas trabajaron con un salario fijo durante el último mes?',
#
# 'En tres meses, ¿esperas que el número total de trabajadores del negocio aumente, disminuya o permanezca igual?',
#
# 'Durante el último mes, ¿tuviste más, menos, o el mismo número de clientes en tu negocio?',
#
# '¿Esperas que en tres meses tengas más, menos o el mismo número de clientes en tu negocio?',
#
# '¿Esperas que las ventas de tu negocio en tres meses sean mayores, menores o iguales?',
#
# '¿Esperas que dentro de tres meses el nivel de inventario incremente, disminuya o permanezca igual?',
#
# 'Actualmente, ¿sientes que tu nivel de inventario es demasiado grande, muy poco o está en su nivel correcto?',
#
# 'En promedio, ¿el precio de venta de los productos que vende este establecimiento aumentó, bajó o permaneció igual a hace un mes?',
#
#
# 'Qué tanto impacta a tu negocio: - El crimen',
#
# 'Qué tanto impacta a tu negocio: - El incremento en el precio de los bienes',
#
# 'Qué tanto impacta a tu negocio: - La competencia',
#
# '¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Bancos',
#
# '¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Proveedores',
#
# '¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Familia',
#
# '¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Gobierno',
#
# '¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Ahorros populares (tandas)',
#
# '¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Crédito privado',
#
# 'Asume que tienes los medios para hacer crecer tu negocio, ¿quisieras que tu negocio creciera? (por ejemplo, con más empleados, más productos, un local más grande)',
#
# 'Horario de apertura',
#
# 'Sexo del dueño o dueña',
#
# '¿El local de su negocio es rentado o propio?',
#
# 'Educación del dueño',
#
# 'Edad del dueño o dueña'

# %% [markdown]
# PREPARANDO LOS DATOS

# %% [markdown]
# # Identificar el modelo de regresión a utilizar

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Revisamos las correlaciones para detectar cuáles variables serán las mejores para predecir la logevidad del negocio
# atraves de la varible: 'Año de apertura del negocio'

# %%
# Revisamos las correlaciones para detectar cuáles variables serán las mejores para predecir la ganacia del negocio
# Atraves de la variable: '¿Cuál sería el salario mensual más bajo que estaría dispuesto a aceptar para cerrar el negocio y'

# %%
Son.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 101 entries, 82 to 692
# Data columns (total 43 columns):
#  #   Column                                                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                                                              --------------  -----
#  0   Fecha registrada                                                                                                                                                    101 non-null    datetime64[ns]
#  1   Latitud Aproximada                                                                                                                                                  101 non-null    float64
# ...

# %%
x = Son[[ '¿Cuántas personas trabajaron para este negocio (con o sin paga) durante el mes anterior?', #Ya en M

'¿Cuántas personas trabajaron con un salario fijo durante el último mes?', #Ya en M

'En tres meses, ¿esperas que el número total de trabajadores del negocio aumente, disminuya o permanezca igual?', # Ya en M

'Durante el último mes, ¿tuviste más, menos, o el mismo número de clientes en tu negocio?', #Ya en M

'¿Esperas que en tres meses tengas más, menos o el mismo número de clientes en tu negocio?', #Ya en M

'¿Esperas que las ventas de tu negocio en tres meses sean mayores, menores o iguales?', #Yo en M

'¿Esperas que dentro de tres meses el nivel de inventario incremente, disminuya o permanezca igual?', # Ya en M

'Actualmente, ¿sientes que tu nivel de inventario es demasiado grande, muy poco o está en su nivel correcto?', # Ya en M

'En promedio, ¿el precio de venta de los productos que vende este establecimiento aumentó, bajó o permaneció igual a hace un mes?', #Ya en M

'Qué tanto impacta a tu negocio: - El crimen', # Ya en M

'Qué tanto impacta a tu negocio: - El incremento en el precio de los bienes', #Ya en M

'Qué tanto impacta a tu negocio: - La competencia', # Ya en M

          #

'¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Bancos', # Ya en M

'¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Proveedores',

'¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Familia',

'¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Ahorros populares (tandas)',

'Asume que tienes los medios para hacer crecer tu negocio, ¿quisieras que tu negocio creciera? (por ejemplo, con más empleados, más productos, un local más grande)', #Ya en M

'Sexo del dueño o dueña', # Ya en M

'¿El local de su negocio es rentado o propio?', # Ya en M


'Edad del dueño o dueña']].values # variables independientes

y = Son['Año de apertura del negocio'].values # variable dependiente

# %%
Son.describe()
# Out:
#                     Fecha registrada  Latitud Aproximada  Longitud Aproximada  \
# count                            101          101.000000           101.000000
# mean   2024-11-16 03:57:27.782178304           28.147797          -109.138971
# min              2024-10-24 18:09:23           19.434200          -122.341400
# 25%              2024-11-13 20:02:38           24.801300          -111.363100
# 50%              2024-11-17 01:57:32           28.927500          -107.477300
# 75%              2024-11-18 18:14:20           29.182600          -107.385000
# max              2024-11-19 09:54:47           47.603400           -99.055900
# std                              NaN            4.024114             3.907231
#
#        Año de apertura del negocio  \
# count                   101.000000
# mean                     18.415842
# min                       0.000000
# 25%                       5.000000
# 50%                      16.000000
# 75%                      29.000000
# ...

# %% [markdown]
# # Correlaciones:

# %%
variables_dependientes = ['Año de apertura del negocio',
                        '¿Cuál sería el salario mensual más bajo que estaría dispuesto a aceptar para cerrar el negocio y',
                        '¿Esperas que en tres meses tengas más, menos o el mismo número de clientes en tu negocio?',
                        '¿Cuántas personas trabajaron para este negocio (con o sin paga) durante el mes anterior?',
                        '¿Cuántas personas trabajaron con un salario fijo durante el último mes?',
                        'En tres meses, ¿esperas que el número total de trabajadores del negocio aumente, disminuya o permanezca igual?',
                        'Durante el último mes, ¿tuviste más, menos, o el mismo número de clientes en tu negocio?',
                        '¿Esperas que en tres meses tengas más, menos o el mismo número de clientes en tu negocio?',
                          '¿Esperas que las ventas de tu negocio en tres meses sean mayores, menores o iguales?',
                          '¿Esperas que dentro de tres meses el nivel de inventario incremente, disminuya o permanezca igual?',
                          'Actualmente, ¿sientes que tu nivel de inventario es demasiado grande, muy poco o está en su nivel correcto?',
                          'En promedio, ¿el precio de venta de los productos que vende este establecimiento aumentó, bajó o permaneció igual a hace un mes?',
                          'Asume que tienes los medios para hacer crecer tu negocio, ¿quisieras que tu negocio creciera? (por ejemplo, con más empleados, más productos, un local más grande)',
                          'Sexo del dueño o dueña', '¿El local de su negocio es rentado o propio?', 'Edad del dueño o dueña',
                          '¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Bancos',
                          '¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Proveedores',
                          '¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Familia',
                          ]
Son_dependientes = Son[variables_dependientes]
Son_full = pd.concat([Son_dependientes, D], axis=1)
matriz_corr = Son_full.corr()

# %%
plt.figure(figsize=(20, 16))  # Ajusta el tamaño de la figura si es necesario
sns.heatmap(matriz_corr, annot=True, linewidth=0.5, fmt='.2f', cmap='coolwarm', cbar=True)
plt.title('Matriz de correlación de datos numéricos y dummies')
plt.show()

# %% [markdown]
# # Modelo de regresion Antiguedad Nanotienda

# %%
In=Son['Año de apertura del negocio'].values
Dep= Son[[
                        '¿Cuál sería el salario mensual más bajo que estaría dispuesto a aceptar para cerrar el negocio y',
                        '¿Esperas que en tres meses tengas más, menos o el mismo número de clientes en tu negocio?',
                        '¿Cuántas personas trabajaron para este negocio (con o sin paga) durante el mes anterior?',
                        '¿Cuántas personas trabajaron con un salario fijo durante el último mes?',
                        'En tres meses, ¿esperas que el número total de trabajadores del negocio aumente, disminuya o permanezca igual?',
                        'Durante el último mes, ¿tuviste más, menos, o el mismo número de clientes en tu negocio?',
                        '¿Esperas que en tres meses tengas más, menos o el mismo número de clientes en tu negocio?',
                          '¿Esperas que las ventas de tu negocio en tres meses sean mayores, menores o iguales?',
                          '¿Esperas que dentro de tres meses el nivel de inventario incremente, disminuya o permanezca igual?',
                          'Actualmente, ¿sientes que tu nivel de inventario es demasiado grande, muy poco o está en su nivel correcto?',
                          'En promedio, ¿el precio de venta de los productos que vende este establecimiento aumentó, bajó o permaneció igual a hace un mes?',
                          'Asume que tienes los medios para hacer crecer tu negocio, ¿quisieras que tu negocio creciera? (por ejemplo, con más empleados, más productos, un local más grande)',
                          'Sexo del dueño o dueña', '¿El local de su negocio es rentado o propio?', 'Edad del dueño o dueña',
                          '¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Bancos',
                          '¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Proveedores',
                          '¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Familia']
                          ].values

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train, x_test, y_train, y_test = train_test_split(Dep, In, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model_regression = LinearRegression()

# %%
model_regression.fit(x_train, y_train) # aprendizaje automático con base en nuestros datos
# Out:
# LinearRegression()

# %%
x_labels = [                         '¿Cuál sería el salario mensual más bajo que estaría dispuesto a aceptar para cerrar el negocio y',
                        '¿Esperas que en tres meses tengas más, menos o el mismo número de clientes en tu negocio?',
                        '¿Cuántas personas trabajaron para este negocio (con o sin paga) durante el mes anterior?',
                        '¿Cuántas personas trabajaron con un salario fijo durante el último mes?',
                        'En tres meses, ¿esperas que el número total de trabajadores del negocio aumente, disminuya o permanezca igual?',
                        'Durante el último mes, ¿tuviste más, menos, o el mismo número de clientes en tu negocio?',
                        '¿Esperas que en tres meses tengas más, menos o el mismo número de clientes en tu negocio?',
                          '¿Esperas que las ventas de tu negocio en tres meses sean mayores, menores o iguales?',
                          '¿Esperas que dentro de tres meses el nivel de inventario incremente, disminuya o permanezca igual?',
                          'Actualmente, ¿sientes que tu nivel de inventario es demasiado grande, muy poco o está en su nivel correcto?',
                          'En promedio, ¿el precio de venta de los productos que vende este establecimiento aumentó, bajó o permaneció igual a hace un mes?',
                          'Asume que tienes los medios para hacer crecer tu negocio, ¿quisieras que tu negocio creciera? (por ejemplo, con más empleados, más productos, un local más grande)',
                          'Sexo del dueño o dueña', '¿El local de su negocio es rentado o propio?', 'Edad del dueño o dueña',
                          '¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Bancos',
                          '¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Proveedores',
                          '¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Familia']
c_label = ['Coeficientes']

# %%
import numpy as np
model_regression.coef_
# Out:
# array([ 1.98091741e-06, -1.12684328e+00,  3.10274395e-02,  3.26575525e-01,
#         4.83655545e-01,  1.48126128e+00, -1.12684328e+00, -2.63107931e+00,
#        -5.35433218e+00, -4.11421653e+00, -1.57486974e+00, -8.89767560e-01,
#         2.58431491e+00,  6.53458898e+00,  4.32920177e+00,  2.87256275e+00,
#        -1.94660648e+00,  6.47723321e+00])

# %%
[model_regression.intercept_]+list(model_regression.coef_)
# Out:
# [22.526169376047335,
#  1.9809174052252272e-06,
#  -1.1268432844956013,
#  0.03102743953354419,
#  0.32657552496723186,
#  0.48365554514919984,
#  1.481261282456005,
#  -1.126843284495602,
#  -2.6310793083061164,
#  -5.354332178860531,
#  -4.114216529364524,
#  -1.5748697371262586,
#  -0.8897675604715092,
#  2.5843149126937868,
#  6.534588981550303,
#  4.329201770318503,
#  2.8725627515864494,
#  -1.946606481973173,
#  6.477233214335801]

# %%
import statsmodels.api as sm

X_with_intercept = sm.add_constant(x_train)

# Ajustar el modelo con statsmodels
sm_model = sm.OLS(y_train, X_with_intercept).fit()

# Mostrar resultados
print(sm_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.389
# Model:                            OLS   Adj. R-squared:                  0.222
# Method:                 Least Squares   F-statistic:                     2.324
# Date:                Sat, 30 Nov 2024   Prob (F-statistic):            0.00833
# Time:                        02:52:24   Log-Likelihood:                -302.27
# No. Observations:                  80   AIC:                             640.5
# Df Residuals:                      62   BIC:                             683.4
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         22.5262     13.495      1.669      0.100      -4.451      49.503
# ...

# %% [markdown]
# Vemos los coeficientes; su valor indica su significancia o peso en la variable de salida y.
#
# Ahora que hemos creado nuestro modelo y lo hemos entrenado, es hora de empezar a predecir, usamos la función predict( ) para pedecir los valores de y en función de los valores x de nuestro conjunto de prueba

# %%
# checar p value menor a 0.5 para que sena significativso

# %%
y_pred = model_regression.predict(x_test) # realiza la predicción con el modelo generado

# %%
residuals = pd.DataFrame({'Real': y_test, 'Predicción': y_pred, 'Residual': y_test - y_pred})
residuals = residuals.sample(n = 6)
residuals = residuals.sort_values(by='Real')
residuals
# Out:
#     Real  Predicción   Residual
# 20   0.0    4.506177  -4.506177
# 9    1.0   11.030327 -10.030327
# 14   3.0   -0.780505   3.780505
# 5    3.0    2.645823   0.354177
# 13   4.0    4.991091  -0.991091
# 2   44.0   15.197011  28.802989

# %% [markdown]
# Ahora calcularemos el coeficiente de determinación R2 para comprobar la precisión de nuestro modelo, mientras mayor sea el R2, mejor será el ajuste del modelo a los datos. Nuestro objetivo es un valor lo más cercano a 1 (100%), que nos indica que tanto se ajusta el modelo a nuestros datos, es decir, que porcentaje de y es explicado por el modelo obtenido.
#
# Importamos la métrica R cuadrada (coeficiente de determinación) de Scikit-Learn y usamos la función r2_score( ) con nuestros valores y:

# %%
import matplotlib.pyplot as plt # importamos la librería pyplot que nos permitirá graficar
import numpy as np # importamos la librería numpy que nos permitirá crear un arreglo para la muestra de 30 datos

# función mágica para desplegar el gráfico en nuestra libreta
# %matplotlib inline

plt.scatter(np.arange(len(residuals)) , residuals['Real'], label = "Real")  # creamos el gráfico con la muestra de datos reales
plt.scatter(np.arange(len(residuals)), residuals['Predicción'], label = "Predicción")  # creamos el gráfico con la muestra de datos de predicción

plt.title("Comparación de: Reales y Predicción") # indicamos el título del gráfico

#plt.xlabel("14 observaciones de costos") # indicamos la etiqueta del eje de las x

plt.ylabel("Costos") # indicamos la etiqueta del eje de las y

plt.legend(loc='upper left') # indicamos la posición de la etiqueta de los datos

plt.show() # desplegamos el gráfico

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.10435852817241609

# %%
model_regression.fit(x_train, y_train) # aprendizaje automático con base en nuestros datos
# Out:
# LinearRegression()

# %% [markdown]
# #Modelo mejorado de regresión año de apertura

# %%
In=Son['Año de apertura del negocio'].values
Dep= Son[[
                          '¿Esperas que dentro de tres meses el nivel de inventario incremente, disminuya o permanezca igual?',
                          '¿El local de su negocio es rentado o propio?', 'Edad del dueño o dueña'
                         ]
                          ].values

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train, x_test, y_train, y_test = train_test_split(Dep, In, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model_regression = LinearRegression()

# %%
model_regression.fit(x_train, y_train) # aprendizaje automático con base en nuestros datos
# Out:
# LinearRegression()

# %%
x_labels = [
                         '¿Esperas que dentro de tres meses el nivel de inventario incremente, disminuya o permanezca igual?',
                          '¿El local de su negocio es rentado o propio?', 'Edad del dueño o dueña']
c_label = ['Coeficientes']

# %%
import numpy as np
model_regression.coef_
# Out:
# array([-5.23747515,  7.27030414,  3.5671141 ])

# %%
[model_regression.intercept_]+list(model_regression.coef_)
# Out:
# [11.366526586074707, -5.237475152548547, 7.270304143607004, 3.5671140977092852]

# %%
import statsmodels.api as sm

X_with_intercept = sm.add_constant(x_train)

# Ajustar el modelo con statsmodels
sm_model = sm.OLS(y_train, X_with_intercept).fit()

# Mostrar resultados
print(sm_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.267
# Model:                            OLS   Adj. R-squared:                  0.238
# Method:                 Least Squares   F-statistic:                     9.237
# Date:                Sat, 30 Nov 2024   Prob (F-statistic):           2.78e-05
# Time:                        02:52:25   Log-Likelihood:                -309.55
# No. Observations:                  80   AIC:                             627.1
# Df Residuals:                      76   BIC:                             636.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         11.3665      6.012      1.891      0.062      -0.607      23.340
# ...

# %%
y_pred = model_regression.predict(x_test) # realiza la predicción con el modelo generado

# %%
residuals = pd.DataFrame({'Real': y_test, 'Predicción': y_pred, 'Residual': y_test - y_pred})
residuals = residuals.sample(n = 6)
residuals = residuals.sort_values(by='Real')
residuals
# Out:
#     Real  Predicción   Residual
# 19   1.0   13.489672 -12.489672
# 5    3.0    6.355443  -3.355443
# 13   4.0    2.788329   1.211671
# 10   6.0   22.430337 -16.430337
# 15  44.0   13.489672  30.510328
# 2   44.0   20.397508  23.602492

# %%
import matplotlib.pyplot as plt # importamos la librería pyplot que nos permitirá graficar
import numpy as np # importamos la librería numpy que nos permitirá crear un arreglo para la muestra de 30 datos

# función mágica para desplegar el gráfico en nuestra libreta
# %matplotlib inline

plt.scatter(np.arange(len(residuals)) , residuals['Real'], label = "Real")  # creamos el gráfico con la muestra de datos reales
plt.scatter(np.arange(len(residuals)), residuals['Predicción'], label = "Predicción")  # creamos el gráfico con la muestra de datos de predicción

plt.title("Comparación de: Reales y Predicción") # indicamos el título del gráfico

#plt.xlabel("14 observaciones de costos") # indicamos la etiqueta del eje de las x

plt.ylabel("Antigüedad") # indicamos la etiqueta del eje de las y

plt.legend(loc='upper left') # indicamos la posición de la etiqueta de los datos

plt.show() # desplegamos el gráfico

# %% [markdown]
# Ahora calcularemos el coeficiente de determinación R2 para comprobar la precisión de nuestro modelo, mientras mayor sea el R2, mejor será el ajuste del modelo a los datos. Nuestro objetivo es un valor lo más cercano a 1 (100%), que nos indica que tanto se ajusta el modelo a nuestros datos, es decir, que porcentaje de y es explicado por el modelo obtenido.
#
# Importamos la métrica R cuadrada (coeficiente de determinación) de Scikit-Learn y usamos la función r2_score( ) con nuestros valores y:

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.2274416037760042

# %%
model_regression.fit(x_train, y_train) # aprendizaje automático con base en nuestros datos
# Out:
# LinearRegression()

# %% [markdown]
# # Modelo de regresion con cantidad de dinero que genera Nano Tienda

# %%
In2=Son['¿Cuál sería el salario mensual más bajo que estaría dispuesto a aceptar para cerrar el negocio y'].values
Dep2= Son[[               'Año de apertura del negocio',
                        '¿Esperas que en tres meses tengas más, menos o el mismo número de clientes en tu negocio?',
                        '¿Cuántas personas trabajaron para este negocio (con o sin paga) durante el mes anterior?',
                        '¿Cuántas personas trabajaron con un salario fijo durante el último mes?',
                        'En tres meses, ¿esperas que el número total de trabajadores del negocio aumente, disminuya o permanezca igual?',
                        'Durante el último mes, ¿tuviste más, menos, o el mismo número de clientes en tu negocio?',
                        '¿Esperas que en tres meses tengas más, menos o el mismo número de clientes en tu negocio?',
                          '¿Esperas que las ventas de tu negocio en tres meses sean mayores, menores o iguales?',
                          '¿Esperas que dentro de tres meses el nivel de inventario incremente, disminuya o permanezca igual?',
                          'Actualmente, ¿sientes que tu nivel de inventario es demasiado grande, muy poco o está en su nivel correcto?',
                          'En promedio, ¿el precio de venta de los productos que vende este establecimiento aumentó, bajó o permaneció igual a hace un mes?',
                          'Asume que tienes los medios para hacer crecer tu negocio, ¿quisieras que tu negocio creciera? (por ejemplo, con más empleados, más productos, un local más grande)',
                          'Sexo del dueño o dueña', '¿El local de su negocio es rentado o propio?', 'Edad del dueño o dueña',
                          '¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Bancos',
                          '¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Proveedores',
                          '¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Familia']
                          ].values

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train, x_test, y_train, y_test = train_test_split(Dep2, In2, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model_regression = LinearRegression()

# %%
model_regression.fit(x_train, y_train) # aprendizaje automático con base en nuestros datos
# Out:
# LinearRegression()

# %%
import numpy as np
model_regression.coef_
# Out:
# array([ 1.27928229e+01, -3.97992039e+02,  7.66124188e+03, -2.45481490e+03,
#         6.57247239e+03,  9.01811509e+03, -3.97992039e+02,  2.16430472e+03,
#         6.64328214e+03, -6.35991263e+03, -8.74459412e+03, -1.02141352e+04,
#         9.20308741e+03, -1.06581556e+04, -2.32277618e+03, -9.38177667e+03,
#         1.78710605e+04,  7.00410048e+03])

# %%
[model_regression.intercept_]+list(model_regression.coef_)
# Out:
# [-11155.134860061207,
#  12.792822927343803,
#  -397.99203946962734,
#  7661.241879119794,
#  -2454.8148985461085,
#  6572.472392348302,
#  9018.115093913782,
#  -397.99203946965105,
#  2164.30472429849,
#  6643.282141126509,
#  -6359.9126279242855,
#  -8744.594116715805,
#  -10214.13524344849,
#  9203.08740606163,
#  -10658.155582541758,
#  -2322.776177469095,
#  -9381.776672948386,
#  17871.06049688728,
#  7004.100475634377]

# %%
import statsmodels.api as sm

X_with_intercept = sm.add_constant(x_train)

# Ajustar el modelo con statsmodels
sm_model = sm.OLS(y_train, X_with_intercept).fit()

# Mostrar resultados
print(sm_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.379
# Model:                            OLS   Adj. R-squared:                  0.209
# Method:                 Least Squares   F-statistic:                     2.228
# Date:                Sat, 30 Nov 2024   Prob (F-statistic):             0.0116
# Time:                        02:52:25   Log-Likelihood:                -929.50
# No. Observations:                  80   AIC:                             1895.
# Df Residuals:                      62   BIC:                             1938.
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.116e+04    3.5e+04     -0.318      0.751   -8.12e+04    5.89e+04
# ...

# %%
y_pred = model_regression.predict(x_test) # realiza la predicción con el modelo generado

# %%
residuals = pd.DataFrame({'Real': y_test, 'Predicción': y_pred, 'Residual': y_test - y_pred})
residuals = residuals.sample(n = 6)
residuals = residuals.sort_values(by='Real')
residuals
# Out:
#     Real    Predicción      Residual
# 7      0  15091.184710 -15091.184710
# 9  15000  20855.640448  -5855.640448
# 5  20000  31006.726407 -11006.726407
# 0  21100  -2083.546787  23183.546787
# 6  30000  -8636.960432  38636.960432
# 1  60000   4724.114486  55275.885514

# %%
import matplotlib.pyplot as plt # importamos la librería pyplot que nos permitirá graficar
import numpy as np # importamos la librería numpy que nos permitirá crear un arreglo para la muestra de 30 datos

# función mágica para desplegar el gráfico en nuestra libreta
# %matplotlib inline

plt.scatter(np.arange(len(residuals)) , residuals['Real'], label = "Real")  # creamos el gráfico con la muestra de datos reales
plt.scatter(np.arange(len(residuals)), residuals['Predicción'], label = "Predicción")  # creamos el gráfico con la muestra de datos de predicción

plt.title("Comparación de: Reales y Predicción") # indicamos el título del gráfico

#plt.xlabel("14 observaciones de costos") # indicamos la etiqueta del eje de las x

plt.ylabel("Costos") # indicamos la etiqueta del eje de las y

plt.legend(loc='upper left') # indicamos la posición de la etiqueta de los datos

plt.show() # desplegamos el gráfico

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# -0.11846063992978584

# %% [markdown]
# # Modelo mejorado de regresión con cantidad de dinero que genera Nano Tienda

# %%
In2=Son['¿Cuál sería el salario mensual más bajo que estaría dispuesto a aceptar para cerrar el negocio y'].values
Dep2= Son[[
                        '¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Proveedores']
                          ].values

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train, x_test, y_train, y_test = train_test_split(Dep2, In2, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model_regression = LinearRegression()

# %%
model_regression.fit(x_train, y_train) # aprendizaje automático con base en nuestros datos
# Out:
# LinearRegression()

# %%
import numpy as np
model_regression.coef_
# Out:
# array([16527.65675057])

# %%
[model_regression.intercept_]+list(model_regression.coef_)
# Out:
# [19927.473684210527, 16527.656750572078]

# %%
import statsmodels.api as sm

X_with_intercept = sm.add_constant(x_train)

# Ajustar el modelo con statsmodels
sm_model = sm.OLS(y_train, X_with_intercept).fit()

# Mostrar resultados
print(sm_model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     3.933
# Date:                Sat, 30 Nov 2024   Prob (F-statistic):             0.0509
# Time:                        02:52:26   Log-Likelihood:                -946.61
# No. Observations:                  80   AIC:                             1897.
# Df Residuals:                      78   BIC:                             1902.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.993e+04   4468.346      4.460      0.000     1.1e+04    2.88e+04
# ...

# %%
y_pred = model_regression.predict(x_test) # realiza la predicción con el modelo generado

# %%
residuals = pd.DataFrame({'Real': y_test, 'Predicción': y_pred, 'Residual': y_test - y_pred})
residuals = residuals.sample(n = 6)
residuals = residuals.sort_values(by='Real')
residuals
# Out:
#      Real    Predicción      Residual
# 2       0  19927.473684 -19927.473684
# 3       0  19927.473684 -19927.473684
# 20   4000  19927.473684 -15927.473684
# 14   5000  19927.473684 -14927.473684
# 19   6000  36455.130435 -30455.130435
# 1   60000  19927.473684  40072.526316

# %%
import matplotlib.pyplot as plt # importamos la librería pyplot que nos permitirá graficar
import numpy as np # importamos la librería numpy que nos permitirá crear un arreglo para la muestra de 30 datos

# función mágica para desplegar el gráfico en nuestra libreta
# %matplotlib inline

plt.scatter(np.arange(len(residuals)) , residuals['Real'], label = "Real")  # creamos el gráfico con la muestra de datos reales
plt.scatter(np.arange(len(residuals)), residuals['Predicción'], label = "Predicción")  # creamos el gráfico con la muestra de datos de predicción

plt.title("Comparación de: Reales y Predicción") # indicamos el título del gráfico

#plt.xlabel("14 observaciones de costos") # indicamos la etiqueta del eje de las x

plt.ylabel("Costos") # indicamos la etiqueta del eje de las y

plt.legend(loc='upper left') # indicamos la posición de la etiqueta de los datos

plt.show() # desplegamos el gráfico

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.10744685296340517

# %% [markdown]
# # Kmeans Antiguedad y dinero que genera Nano tiendas
# usar betas de regresion por eso no estendarize
# varibles estendarizadas
# estendarizado = # - / promeido

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
# %matplotlib inline

# %%
np.random.seed(0)

# %%
Km=Son[['¿Cuál sería el salario mensual más bajo que estaría dispuesto a aceptar para cerrar el negocio y','Año de apertura del negocio',
                        '¿Cuántas personas trabajaron para este negocio (con o sin paga) durante el mes anterior?',
                        '¿Cuántas personas trabajaron con un salario fijo durante el último mes?',
                        'En tres meses, ¿esperas que el número total de trabajadores del negocio aumente, disminuya o permanezca igual?',
                        'Durante el último mes, ¿tuviste más, menos, o el mismo número de clientes en tu negocio?',
                        '¿Esperas que en tres meses tengas más, menos o el mismo número de clientes en tu negocio?',
                          '¿Esperas que las ventas de tu negocio en tres meses sean mayores, menores o iguales?',
                          '¿Esperas que dentro de tres meses el nivel de inventario incremente, disminuya o permanezca igual?',
                          'Actualmente, ¿sientes que tu nivel de inventario es demasiado grande, muy poco o está en su nivel correcto?',
                          'En promedio, ¿el precio de venta de los productos que vende este establecimiento aumentó, bajó o permaneció igual a hace un mes?',
                          'Asume que tienes los medios para hacer crecer tu negocio, ¿quisieras que tu negocio creciera? (por ejemplo, con más empleados, más productos, un local más grande)',
                          'Sexo del dueño o dueña', '¿El local de su negocio es rentado o propio?', 'Edad del dueño o dueña',
                          '¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Bancos',
                          '¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Proveedores',
                          '¿De cuáles de las siguientes opciones recibiste crédito para operar tu negocio? - Familia']
                          ]

# %%
import pandas as pd
from sklearn import preprocessing
scalar = preprocessing.StandardScaler()
X = scalar.fit_transform(Km)
X
# Out:
# array([[-0.41304098,  1.30653549, -0.64694615, ..., -0.46569032,
#         -0.63464776,  1.65551827],
#        [-0.05940101,  1.79866153,  0.66865576, ...,  2.14734979,
#          1.57567719,  1.65551827],
#        [-0.68507173,  1.79866153, -1.52401409, ..., -0.46569032,
#         -0.63464776, -0.60404045],
#        ...,
#        [-0.68507173,  1.0253206 , -1.08548012, ..., -0.46569032,
#          1.57567719, -0.60404045],
#        [-0.68507173,  0.11137223, -1.52401409, ..., -0.46569032,
#         -0.63464776, -0.60404045],
#        [ 2.03523575, -1.29470219, -0.64694615, ..., -0.46569032,
#         -0.63464776, -0.60404045]])

# %%
k_means = KMeans(init = "k-means++", n_clusters = 4, n_init = 12)

# %%
k_means.fit(X)
# Out:
# KMeans(n_clusters=4, n_init=12)

# %%
k_means_labels = k_means.labels_
Km['cluster'] = k_means_labels
Km['cluster']
# Out:
# <ipython-input-163-c4b9d98ebea2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Km['cluster'] = k_means_labels
# 82     2
# 83     0
# 554    3
# 555    0
# 558    1
#       ..
# 688    2
# 689    1
# 690    2
# 691    0
# 692    1
# Name: cluster, Length: 101, dtype: int32

# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.cluster import KMeans

# ... (your existing code to define scalar, X, k_means, and fit the model) ...

k_means_cluster_centers = k_means.cluster_centers_

# De-standardize the centroids
original_centroids = (k_means.cluster_centers_ * scalar.scale_) + scalar.mean_

# Get the original column names (excluding the 'cluster' column)
original_columns = Km.columns[Km.columns != 'cluster']

# Create the DataFrame using the original columns
centros = pd.DataFrame(original_centroids, columns=original_columns)

centros
# Out:
#    ¿Cuál sería el salario mensual más bajo que estaría dispuesto a aceptar para cerrar el negocio y  \
# 0                                       14027.529412
# 1                                       56405.550000
# 2                                       11765.000000
# 3                                       29431.916667
#
#    Año de apertura del negocio  \
# 0                    23.294118
# 1                     5.750000
# 2                    19.600000
# 3                    23.541667
#
#    ¿Cuántas personas trabajaron para este negocio (con o sin paga) durante el mes anterior?  \
# 0                                           2.176471
# 1                                           3.250000
# 2                                           2.500000
# 3                                           6.208333
#
#    ¿Cuántas personas trabajaron con un salario fijo durante el último mes?  \
# 0                                           1.764706
# ...

# %%
#k_means_cluster_centers = k_means.cluster_centers_
#k_means_cluster_centersk_means_cluster_centers = k_means.cluster_centers_

#original_centroids = (k_means.cluster_centers_ * scalar.scale_) + scalar.mean_

#centros = pd.DataFrame(original_centroids,columns=Km.columns)




# De-standardize the centroids

#centros

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)  # Reduce to 2 dimensions for visualization
principalComponents = pca.fit_transform(X).copy()
principalDf = pd.DataFrame(data=principalComponents, columns=['principal component 1', 'principal component 2'])
principalDf['cluster'] = Km['cluster'].reset_index(drop=True)
principalDf
# Out:
#      principal component 1  principal component 2  cluster
# 0                -2.430626               1.538907        2
# 1                -0.819085               1.726893        0
# 2                 0.357961               0.017925        3
# 3                -3.220190              -1.813634        0
# 4                 0.434422              -0.864594        1
# ..                     ...                    ...      ...
# 96                0.113459              -1.437277        2
# 97                0.494991              -2.621958        1
# 98               -1.640275               1.480296        2
# 99               -2.518274               0.352586        0
# 100               0.593097              -2.427503        1
#
# [101 rows x 3 columns]

# %%
fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(1, 1, 1)
ax.set_xlabel('Principal Component 1', fontsize=15)
ax.set_ylabel('Principal Component 2', fontsize=15)
ax.set_title('2 component PCA', fontsize=20)
targets = np.unique(y)  # Get unique cluster labels
colors = ['r', 'g', 'b', 'c', 'm', 'y', 'k']  # Adjust colors as needed

for target, color in zip(targets, colors):
    indicesToKeep = principalDf['cluster'] == target
    ax.scatter(principalDf.loc[indicesToKeep, 'principal component 1'],
              principalDf.loc[indicesToKeep, 'principal component 2'],
              c=color, s=50)
ax.legend(targets)
ax.grid
# Out:
# <bound method _AxesBase.grid of <Axes: title={'center': '2 component PCA'}, xlabel='Principal Component 1', ylabel='Principal Component 2'>>
